# %% [markdown]
# <a href="https://colab.research.google.com/github/massefi/MyLeetcodePractice/blob/main/MyLeetcodeExcercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Mount Google Drive (Strongly Recommended)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 2. Set up Git
# !git config --global user.name "massefi"
# !git config --global user.email "mehdi.assefi@gmail.com"

# %%
# 3. Clone your repository inside Google Drive
# %cd /content/drive/MyDrive

# Replace with your actual repo URL
# !git clone https://github.com/massefi/MyLeetcodePractice.git
# Out:
# /content/drive/MyDrive
# Cloning into 'MyLeetcodePractice'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), done.

# %%
# %cd my-colab-notebooks
# !ls
# Out:
# [Errno 2] No such file or directory: 'my-colab-notebooks'
# /content/drive/MyDrive
#  BERT_1_500.ipynb
#  Bert.ipynb
#  case_study_data.csv
# 'Colab Notebooks'
# 'Data Science II'
#  dengirojhilat.pdf
#  df_moments.txt
#  df_moments.xls
#  directory
#  directory1
#  directory.7z
# 'fake-news-net-numeric-kolii - Copy.txt'
# 'fake-news-net-numeric-kolii - Copy.xls'
#  fraud_moments.txt
#  fraud_moments.xls
#  functions.txt
#  ktrain
#  Libraries.txt
# 'LLM Workshop'
#  Mehdi_Assefi___Mercury.pdf
#  Mehdi_Assefi_Multi-Agent_Powered_RAG_Retrieval_Assessment.html
#  Mehdi_AssefiORCL.pdf
# 'Mehdi, [May 8, 2025 at 1:38 PM]'$'\n''Meta MLSD'$'\n''.txt'
# 'Mehdi, [Nov 14, 2025 at 1:32 PM]'$'\n''ADP'$'\n''.txt'
#  MetaB.mp3
#  MetaMLSD.mp3
#  morsal.ipynb
#  MyLeetcodePractice
#  pricing_demand_data.csv
# 'Room 523 Microbiology'
# 'Saved from Chrome'
# 'Scanned Jul 18, 2025 at 2:44:39 PM.pdf'
# 'Scanned Jul 18, 2025 at 2:52:19 PM.pdf'
# 'Scanned Jul 18, 2025 at 2:55:39 PM.pdf'
# ...

# %%
# !mkdir -p "Excercise"     # Replace with your desired folder name

# %%
# !mv /content/drive/MyDrive/MyLeetcodePractice.ipynb Excercise/
# Out:
# mv: cannot stat '/content/drive/MyDrive/MyLeetcodePractice.ipynb': No such file or directory

# %%
# 1. Check where your current notebook actually is
# !ls /content/
# Out:
# drive  sample_data

# %%
# 2. See what's in your MyDrive folder
# !ls "/content/drive/MyDrive"
# Out:
#  BERT_1_500.ipynb
#  Bert.ipynb
#  case_study_data.csv
# 'Colab Notebooks'
# 'Data Science II'
#  dengirojhilat.pdf
#  df_moments.txt
#  df_moments.xls
#  directory
#  directory1
#  directory.7z
#  Excercise
# 'fake-news-net-numeric-kolii - Copy.txt'
# 'fake-news-net-numeric-kolii - Copy.xls'
#  fraud_moments.txt
#  fraud_moments.xls
#  functions.txt
#  ktrain
#  Libraries.txt
# 'LLM Workshop'
#  Mehdi_Assefi___Mercury.pdf
#  Mehdi_Assefi_Multi-Agent_Powered_RAG_Retrieval_Assessment.html
#  Mehdi_AssefiORCL.pdf
# 'Mehdi, [May 8, 2025 at 1:38 PM]'$'\n''Meta MLSD'$'\n''.txt'
# 'Mehdi, [Nov 14, 2025 at 1:32 PM]'$'\n''ADP'$'\n''.txt'
#  MetaB.mp3
#  MetaMLSD.mp3
#  morsal.ipynb
#  MyLeetcodePractice
#  pricing_demand_data.csv
# 'Room 523 Microbiology'
# 'Saved from Chrome'
# 'Scanned Jul 18, 2025 at 2:44:39 PM.pdf'
# 'Scanned Jul 18, 2025 at 2:52:19 PM.pdf'
# 'Scanned Jul 18, 2025 at 2:55:39 PM.pdf'
# 'Scanned Jul 18, 2025 at 3:02:18 PM.pdf'
# 'Stanford ML Course'
#  telegram_audio.ogg
# ...

# %%
# 3. Look for your notebook (search broadly)
# !find /content -name "*.ipynb" | head -10
